# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web

sp500 = web.DataReader('^GSPC', data_source='yahoo',start='1/1/2000', end='1/30/2020')
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5051 entries, 2000-01-03 to 2020-01-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       5051 non-null   float64
#  1   Low        5051 non-null   float64
#  2   Open       5051 non-null   float64
#  3   Close      5051 non-null   float64
#  4   Volume     5051 non-null   int64
#  5   Adj Close  5051 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 276.2 KB

# %%
sp500['50d'] = np.round(sp500['Close'].rolling(50).mean(), 2)
sp500['200d'] =np.round(sp500['Close'].rolling(200).mean(), 2)
sp500[['Close','50d','200d']].plot(grid=True, figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp500 = web.DataReader('^GSPC', data_source='yahoo',start='1/1/2019', end='1/30/2020')
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 272 entries, 2019-01-02 to 2020-01-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       272 non-null    float64
#  1   Low        272 non-null    float64
#  2   Open       272 non-null    float64
#  3   Close      272 non-null    float64
#  4   Volume     272 non-null    int64
#  5   Adj Close  272 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 14.9 KB

# %%
#Pandas
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([10, 20, 30, 40], columns=['numbers'],index=['a', 'b', 'c', 'd'])
print(df)
print(df.info())
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   numbers  4 non-null      int64
# dtypes: int64(1)
# memory usage: 48.0+ bytes
# None

# %%
df = pd.DataFrame([[10,11,12], [20,21,22], [30,31,32], [40,41,42]], columns=['N0','N1','N2'],index=['a', 'b', 'c', 'd'])
print(df)
print(df.info())
# Out:
#    N0  N1  N2
# a  10  11  12
# b  20  21  22
# c  30  31  32
# d  40  41  42
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   N0      4 non-null      int64
#  1   N1      4 non-null      int64
#  2   N2      4 non-null      int64
# dtypes: int64(3)
# memory usage: 112.0+ bytes
# None

# %%
df = pd.DataFrame([[10,11,12], [20,21,22], [30,31,32], [40,41,42]], columns=['N0','N1','N2'])
print(df)
print(df.info())
# Out:
#    N0  N1  N2
# 0  10  11  12
# 1  20  21  22
# 2  30  31  32
# 3  40  41  42
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   N0      4 non-null      int64
#  1   N1      4 non-null      int64
#  2   N2      4 non-null      int64
# dtypes: int64(3)
# memory usage: 160.0 bytes
# None

# %%
df = pd.DataFrame([[10,11,12], [20,21,22], [30,31,32], [40,41,42]], columns=['N0','N1','N2'],index=['a', 'b', 'c', 'd'])
print(df)
print(df.info())
# Out:
#    N0  N1  N2
# a  10  11  12
# b  20  21  22
# c  30  31  32
# d  40  41  42
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   N0      4 non-null      int64
#  1   N1      4 non-null      int64
#  2   N2      4 non-null      int64
# dtypes: int64(3)
# memory usage: 112.0+ bytes
# None

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['N0', 'N1', 'N2'], dtype='object')

# %%
df.sum()
# Out:
# N0    100
# N1    104
# N2    108
# dtype: int64

# %%
df*2
# Out:
#    N0  N1  N2
# a  20  22  24
# b  40  42  44
# c  60  62  64
# d  80  82  84

# %%
stn = np.random.standard_normal((500,2))

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(stn, bins=50)
plt.grid(True)
plt.title('Distribution')
plt.xlabel('Dist')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
type(stn)
# Out:
# numpy.ndarray
